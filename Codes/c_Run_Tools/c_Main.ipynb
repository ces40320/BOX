# %% [markdown]
# # c_Run_Tools Runner
#
# `run_opensim_pipeline.py`를 노트북에서 셀 단위로 실행하기 위한 작업 노트북입니다.
#
# - 단일 피험자 / 조건 실행
# - `--dry-run` 점검
# - 세그먼트 단위 제한 실행
# - (옵션) 여러 조건 반복 실행

# %%
import os
import sys
import subprocess

# 노트북 실행 위치가 어디든 동작하도록 경로를 정렬
repo_root = os.getcwd()
if not os.path.isdir(os.path.join(repo_root, "Codes")):  # if you run this notebook from other directory, change below
    repo_root = r"C:/Users/ok/Documents/GitHub/BOX"      # TODO: change to your path

work_dir = os.path.join(repo_root, "Codes", "c_Run_Tools")
os.chdir(work_dir)

if work_dir not in sys.path:
    sys.path.insert(0, work_dir)
codes_dir = os.path.dirname(work_dir)
if codes_dir not in sys.path:
    sys.path.insert(0, codes_dir)


def run_cmd_show_output(cmd):
    """Notebook에서 subprocess 출력 누락을 피하기 위한 helper."""
    print("[RUN]", " ".join(cmd))
    result = subprocess.run(cmd, capture_output=True, text=True)

    if result.stdout:
        print(result.stdout)
    if result.stderr:
        print("[stderr]")
        print(result.stderr)

    if result.returncode != 0:
        raise RuntimeError(f"Command failed with exit code {result.returncode}")


print("cwd:", os.getcwd())
print("work_dir:", work_dir)
# Out:
# cwd: C:\Users\ok\Documents\GitHub\BOX\Codes\c_Run_Tools
# work_dir: C:/Users/ok/Documents/GitHub/BOX\Codes\c_Run_Tools

# %%
from SUB_Info import subjects

print("Available subjects:", list(subjects.keys()))

namecode = "260306_KTY"  # TODO: 필요 시 변경
print("Conditions:", list(subjects[namecode]["conditions"].keys()))
# Out:
# Available subjects: ['240124_PJH', '260306_KTY']
# Conditions: ['7kg_10bpm', '15kg_10bpm', '7kg_16bpm', '15kg_16bpm']

# %%
# 단일 피험자/조건 dry-run 점검
namecode = "260306_KTY"     # TODO
condition = "7kg_10bpm"     # TODO
tools = "extload, ik"               # 현재 구현 범위
segments = "1AB,1BC,1CA"                 # 검증용 소량 실행

cmd = [
    sys.executable,
    "run_opensim_pipeline.py",
    "--namecode", namecode,
    "--condition", condition,
    "--tools", tools,
    "--segments", segments,
    "--dry-run",
]

run_cmd_show_output(cmd)

# %%
# 단일 피험자/조건 실제 실행
# 주의: 실제 파일 생성/실행이 발생합니다.
namecode = "240124_PJH"            # TODO
condition = "7kg_10bpm_trial1"     # TODO
tools = "extload,ik"
segments = "1U"                    # 처음엔 1개 세그먼트로 권장

cmd = [
    sys.executable,
    "run_opensim_pipeline.py",
    "--namecode", namecode,
    "--condition", condition,
    "--tools", tools,
    "--segments", segments,
    # "--dry-run",
]

run_cmd_show_output(cmd)

# %%
# 여러 조건 일괄 dry-run (옵션)
namecode = "260306_KTY"  # TODO
conditions = [
    "7kg_10bpm",
]
tools = "extload,ik"

for cond in conditions:
    cmd = [
        sys.executable,
        "run_opensim_pipeline.py",
        "--namecode", namecode,
        "--condition", cond,
        "--tools", tools,
        # "--dry-run",
    ]
    print()
    run_cmd_show_output(cmd)
# Out:
# [RUN] c:\Users\ok\anaconda3\envs\opensim_scripting\python.exe run_opensim_pipeline.py --namecode 260306_KTY --condition 7kg_10bpm --tools extload,ik
# [OpenSim Pipeline]
#   namecode  : 260306_KTY
#   subject   : SUB2
#   protocol  : Asymmetric
#   condition : 7kg_10bpm
#   tools     : ['extload', 'ik']
#   apps      : ['MeasuredEHF', 'HeavyHand', 'preRiCTO', 'postRiCTO']
#   dry_run   : False
#   segments  : 33 selected
#   error_log : ['7AB']
#
# [Structure Validation - Sample]
#   condition : 7kg_10bpm
#   section   : AB
#   segment   : 1AB
#   app       : MeasuredEHF
#   markers   : C:\Users\ok\Documents\GitHub\BOX\OpenSim_Process\_Main_\Asymmetric\SUB2\7kg_10bpm\AB\Markers
#   extload   : C:\Users\ok\Documents\GitHub\BOX\OpenSim_Process\_Main_\Asymmetric\SUB2\7kg_10bpm\AB\ExtLoad
#   ik        : C:\Users\ok\Documents\GitHub\BOX\OpenSim_Process\_Main_\Asymmetric\SUB2\7kg_10bpm\AB\IK
#   trc_path  : C:\Users\ok\Documents\GitHub\BOX\OpenSim_Process\_Main_\Asymmetric\SUB2\7kg_10bpm\AB\Markers\SUB2_7kg_10bpm_1AB.trc
#   ext_xml   : C:\Users\ok\Documents\GitHub\BOX\OpenSim_Process\_Main_\Asymmetric\SUB2\7kg_10bpm\AB\ExtLoad\SETUP_ExtLoad_7kg_10bpm_1AB_MeasuredEHF.xml
#   ik_xml    : C:\Users\ok\Documents\GitHub\BOX\OpenSim_Process\_Main_\Asymmetric\SUB2\7kg_10bpm\AB\IK\SETUP_IK_7kg_10bpm_1AB.xml
# [OK] ExtLoad setup: C:\Users\ok\Documents\GitHub\BOX\OpenSim_Process\_Main_\Asymmetric\SUB2\7kg_10bpm\AB\ExtLoad\SETUP_ExtLoad_7kg_10bpm_1AB_MeasuredEHF.xml
#
# [stderr]
# Traceback (most recent call last):
#   File "C:\Users\ok\Documents\GitHub\BOX\Codes\c_Run_Tools\run_opensim_pipeline.py", line 164, in <module>
#     main()
#   File "C:\Users\ok\Documents\GitHub\BOX\Codes\c_Run_Tools\run_opensim_pipeline.py", line 151, in main
#     ik_path = run_ik(
#               ^^^^^^^
#   File "C:\Users\ok\Documents\GitHub\BOX\Codes\c_Run_Tools\opensim_pipeline_handlers.py", line 72, in run_ik
#     model = osim.Model(model_path)
#             ^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ok\anaconda3\envs\opensim_scripting\Lib\opensim\simulation.py", line 28156, in __init__
#     _simulation.Model_swiginit(self, _simulation.new_Model(*args))
#                                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: std::exception in 'OpenSim::Model::Model(std::string const &)': Object: Cannot open file C:\Users\ok\Documents\GitHub\BOX\OpenSim_Process\_Main_\Asymmetric\SUB2\Model_osim\SUB2_Scaled.osim. It may not exist or you do not have permission to read it.
# 	Thrown at Object.cpp:106 in Object().
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[15], line 18
#       9 cmd = [
#      10     sys.executable,
#      11     "run_opensim_pipeline.py",
#    (...)     15     # "--dry-run",
#      16 ]
#      17 print()
# ---> 18 run_cmd_show_output(cmd)
#
# Cell In[13], line 32, in run_cmd_show_output(cmd)
#      29     print(result.stderr)
#      31 if result.returncode != 0:
# ---> 32     raise RuntimeError(f"Command failed with exit code {result.returncode}")
#
# RuntimeError: Command failed with exit code 1

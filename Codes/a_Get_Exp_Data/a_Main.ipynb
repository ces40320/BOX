# %% [markdown]
# # a_Get_Exp_Data Runner
#
# `run_get_exp_data.py`를 노트북에서 셀 단위로 실행하기 위한 작업 노트북입니다.
#
# - 단일 피험자 / 다중 피험자 실행
# - `dry_run` 점검
# - 조건별 디버깅 전 실행

# %%
import os
import sys

# 노트북 실행 위치가 어디든 동작하도록 경로를 정렬
repo_root = os.getcwd()
if not os.path.isdir(os.path.join(repo_root, "Codes")): # if you want to run this notebook from other directory, change the path below
    repo_root = r"C:/Users/ok/Documents/GitHub/BOX"     # TODO: change to your path

work_dir = os.path.join(repo_root, "Codes", "a_Get_Exp_Data")
os.chdir(work_dir)

if work_dir not in sys.path:
    sys.path.insert(0, work_dir)
codes_dir = os.path.dirname(work_dir)
if codes_dir not in sys.path:
    sys.path.insert(0, codes_dir)

print("cwd:", os.getcwd())
print("work_dir:", work_dir)
# Out:
# cwd: C:\Users\ok\Documents\GitHub\BOX\Codes\a_Get_Exp_Data
# work_dir: C:/Users/ok/Documents/GitHub/BOX\Codes\a_Get_Exp_Data

# %%
import PATH_RULE as _path
from run_get_exp_data import process_subject

print("Available subjects:", _path.DATA_SUB_NAMECODE_li)
# Out:
# Available subjects: ['240124_PJH', '260306_KTY']

# %%
# 단일 피험자 dry-run 점검
namecode = "240124_PJH"  # TODO: 필요 시 변경
process_subject(namecode, dry_run=True)

# %%
# 단일 피험자 실제 실행
dry_run = False
namecode = "260306_KTY"  # TODO: 필요 시 변경
process_subject(namecode, dry_run=dry_run)
# Out:
# ============================================================
# [260306_KTY]  SUB2  protocol=Asymmetric  method=manual_window
#   C3D dir : E:\Dropbox\SEL\BOX\Experiment\260306_KTY\Labeled
#   Rigid dir: E:\Dropbox\SEL\BOX\Experiment\260306_KTY\RigidBody
#   Output  : C:\Users\ok\Documents\GitHub\BOX\OpenSim_Process\_Main_\Asymmetric\SUB2
#   APPs    : ['MeasuredEHF', 'HeavyHand', 'preRiCTO', 'postRiCTO']
# ============================================================
#     [WARN] Multiple RigidBody CSVs match '7kg_10bpm': ['7kg_10bpm.csv', '7kg_10bpm_1000.csv']
#
#   [7kg_10bpm]  C3D=OK  Rigid=OK  cycles=11
#     C3D  : 7kg_10bpm.c3d
#     Rigid: 7kg_10bpm.csv
#     error_log: ['7AB']
#     ── dry-run plan ──
#     C3D candidates (1):
#       7kg_10bpm.c3d  <- selected
#     Rigid candidates (2):
#       7kg_10bpm.csv  <- selected
#       7kg_10bpm_1000.csv
#     BPM extracted: 10
#     Window duration: 6.0s
#     Planned outputs: 33 TRC + 66 MOT (2/4 APPs implemented)
#       section AB: ['1AB', '2AB', '3AB', '4AB', '5AB', '6AB', '7AB', '8AB', '9AB', '10AB', '11AB']
#       section BC: ['1BC', '2BC', '3BC', '4BC', '5BC', '6BC', '7BC', '8BC', '9BC', '10BC', '11BC']
#       section CA: ['1CA', '2CA', '3CA', '4CA', '5CA', '6CA', '7CA', '8CA', '9CA', '10CA', '11CA']
#     Example paths for seg='1AB':
#       TRC : C:\Users\ok\Documents\GitHub\BOX\OpenSim_Process\_Main_\Asymmetric\SUB2\7kg_10bpm\AB\Markers\SUB2_7kg_10bpm_1AB.trc
#       MOT : C:\Users\ok\Documents\GitHub\BOX\OpenSim_Process\_Main_\Asymmetric\SUB2\7kg_10bpm\AB\ExtLoad\SUB2_7kg_10bpm_1AB_ExtLoad_MeasuredEHF.mot
#       MOT : C:\Users\ok\Documents\GitHub\BOX\OpenSim_Process\_Main_\Asymmetric\SUB2\7kg_10bpm\AB\ExtLoad\SUB2_7kg_10bpm_1AB_ExtLoad_HeavyHand.mot
#       MOT : [SKIP]  preRiCTO  (not implemented)
#       MOT : [SKIP]  postRiCTO  (not implemented)
#     [WARN] APPs not implemented (MOT will be skipped): ['preRiCTO', 'postRiCTO']
#     [WARN] 2 Rigid candidates matched (first selected)
#
#   [15kg_10bpm]  C3D=OK  Rigid=MISSING  cycles=11
#     C3D  : 15kg_10bpm.c3d
#     error_log: ['4CA']
#     [ERROR] No Rigid CSV matched '15kg_10bpm' in E:\Dropbox\SEL\BOX\Experiment\260306_KTY\RigidBody
#
#   [15kg_16bpm]  C3D=OK  Rigid=MISSING  cycles=10
#     C3D  : 15kg_16bpm.c3d
#     [ERROR] No Rigid CSV matched '15kg_16bpm' in E:\Dropbox\SEL\BOX\Experiment\260306_KTY\RigidBody
#
#   [7kg_16bpm]  C3D=OK  Rigid=MISSING  cycles=10
#     C3D  : 7kg_16bpm.c3d
#     [ERROR] No Rigid CSV matched '7kg_16bpm' in E:\Dropbox\SEL\BOX\Experiment\260306_KTY\RigidBody

# %%
# 여러 피험자 일괄 실행 (옵션)
dry_run = True
subject_list = [
    # "240124_PJH",
    "260306_KTH",
    
]

for nc in subject_list:
    process_subject(nc, dry_run=dry_run)
